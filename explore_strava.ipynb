# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../datasets/strava_edges_2021.csv')

# %% [markdown]
# ### Basic dataset info
#
# 1. `edge_uid` is strava specific ID for a street
# 2. `osm_reference_id` should be OpenStreetMap way ID - could be a way to match other datasets
# 3. valuable number: `forward_trip_count`/`reverse_trip_count`
# 4. It's possible to download commute data only - leisure trips excluded: Find the quantitative difference
# 5. maybe export dataset by month/week - possible to aggregate and match with other datasets

# %%
display(df.head())
display(f"Shape: {df.shape}")
display("Columns:", df.columns)
display(df.describe())
# Out:
#     edge_uid activity_type  year  forward_trip_count  reverse_trip_count  \
# 0  160893973          Ride  2021                   5                  30
# 1  160900085          Ride  2021                   5                   0
# 2  160901788          Ride  2021                  65                  65
# 3  160901895          Ride  2021                 255                 400
# 4  160902450          Ride  2021                  75                 185
#
#    forward_people_count  reverse_people_count  forward_commute_trip_count  \
# 0                     5                    15                           0
# 1                     5                     0                           0
# 2                    60                    55                           5
# 3                    85                   100                          25
# 4                    70                   130                           5
#
#    reverse_commute_trip_count  forward_leisure_trip_count  ...  \
# 0                           0                           5  ...
# 1                           0                           5  ...
# 2                           5                          60  ...
# 3                          20                         230  ...
# 4                          15                          70  ...
#
#    reverse_20_34_people_count  forward_35_54_people_count  \
# 0                           0                           5
# 1                           0                           5
# 2                          20                          25
# 3                          20                          55
# 4                          30                          35
#
#    reverse_35_54_people_count  forward_55_64_people_count  \
# 0                          10                           0
# 1                           0                           0
# 2                          20                           5
# 3                          55                           0
# 4                          60                           0
#
#    reverse_55_64_people_count  forward_65_plus_people_count  \
# 0                           0                             0
# 1                           0                             0
# 2                           5                             0
# 3                           5                             0
# 4                          10                             0
#
#    reverse_65_plus_people_count  forward_average_speed  reverse_average_speed  \
# 0                             0                   5.94                   3.15
# 1                             0                   1.36                   0.00
# 2                             0                   0.56                   0.35
# 3                             0                   2.66                   4.61
# 4                             5                   2.03                   2.60
#
#    osm_reference_id
# 0          93103358
# 1          65201855
# 2          33968694
# 3         108343596
# 4          74064352
#
# [5 rows x 34 columns]
# 'Shape: (193812, 34)'
# 'Columns:'
# Index(['edge_uid', 'activity_type', 'year', 'forward_trip_count',
#        'reverse_trip_count', 'forward_people_count', 'reverse_people_count',
#        'forward_commute_trip_count', 'reverse_commute_trip_count',
#        'forward_leisure_trip_count', 'reverse_leisure_trip_count',
#        'forward_morning_trip_count', 'reverse_morning_trip_count',
#        'forward_evening_trip_count', 'reverse_evening_trip_count',
#        'forward_male_people_count', 'reverse_male_people_count',
#        'forward_female_people_count', 'reverse_female_people_count',
#        'forward_unspecified_people_count', 'reverse_unspecified_people_count',
#        'forward_13_19_people_count', 'reverse_13_19_people_count',
#        'forward_20_34_people_count', 'reverse_20_34_people_count',
#        'forward_35_54_people_count', 'reverse_35_54_people_count',
#        'forward_55_64_people_count', 'reverse_55_64_people_count',
#        'forward_65_plus_people_count', 'reverse_65_plus_people_count',
#        'forward_average_speed', 'reverse_average_speed', 'osm_reference_id'],
#       dtype='object')
#            edge_uid      year  forward_trip_count  reverse_trip_count  \
# count  1.938120e+05  193812.0       193812.000000       193812.000000
# mean   1.619876e+08    2021.0          328.296674          299.673266
# std    1.366626e+06       0.0         1000.382059          947.005243
# min    1.608657e+08    2021.0            0.000000            0.000000
# 25%    1.610366e+08    2021.0           10.000000           10.000000
# 50%    1.610995e+08    2021.0           50.000000           40.000000
# 75%    1.619703e+08    2021.0          255.000000          220.000000
# max    1.651605e+08    2021.0        27120.000000        27210.000000
#
#        forward_people_count  reverse_people_count  forward_commute_trip_count  \
# count         193812.000000         193812.000000               193812.000000
# mean             122.016774            114.457619                   52.651229
# std              269.185387            261.843734                  243.399422
# min                0.000000              0.000000                    0.000000
# 25%                5.000000              5.000000                    0.000000
# 50%               25.000000             25.000000                    5.000000
# 75%              120.000000            105.000000                   20.000000
# max             4775.000000           4790.000000                 7965.000000
#
#        reverse_commute_trip_count  forward_leisure_trip_count  \
# count               193812.000000               193812.000000
# mean                    44.795859                  275.645445
# std                    216.467870                  804.559041
# min                      0.000000                    0.000000
# 25%                      0.000000                   10.000000
# 50%                      5.000000                   40.000000
# 75%                     20.000000                  215.000000
# max                   8030.000000                21610.000000
#
#        reverse_leisure_trip_count  ...  reverse_20_34_people_count  \
# count               193812.000000  ...               193812.000000
# mean                   254.877407  ...                   40.220265
# std                    773.482855  ...                  106.047168
# min                      0.000000  ...                    0.000000
# 25%                     10.000000  ...                    0.000000
# 50%                     35.000000  ...                    5.000000
# 75%                    190.000000  ...                   35.000000
# max                  21775.000000  ...                 2175.000000
#
#        forward_35_54_people_count  reverse_35_54_people_count  \
# count               193812.000000               193812.000000
# mean                    55.902472                   52.790952
# std                    115.831211                  112.967226
# min                      0.000000                    0.000000
# 25%                      5.000000                    5.000000
# 50%                     15.000000                   10.000000
# 75%                     55.000000                   50.000000
# max                   1810.000000                 1810.000000
#
#        forward_55_64_people_count  reverse_55_64_people_count  \
# count               193812.000000                193812.00000
# mean                     4.376638                     4.11925
# std                      9.626298                     9.36967
# min                      0.000000                     0.00000
# 25%                      0.000000                     0.00000
# 50%                      0.000000                     0.00000
# 75%                      5.000000                     5.00000
# max                    125.000000                   130.00000
#
#        forward_65_plus_people_count  reverse_65_plus_people_count  \
# count                 193812.000000                 193812.000000
# mean                       1.105607                      1.054579
# std                        2.968917                      2.965756
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                       45.000000                     50.000000
#
#        forward_average_speed  reverse_average_speed  osm_reference_id
# count          193812.000000          193812.000000      1.938120e+05
# mean                4.053632               3.816700      2.882771e+08
# std                 4.211878               5.409011      2.776948e+08
# min                 0.000000               0.000000      4.019269e+06
# 25%                 2.000000               1.800000      5.201029e+07
# 50%                 3.740000               3.600000      1.776555e+08
# 75%                 5.400000               5.270000      4.308205e+08
# max               363.990000            1468.950000      1.023971e+09
#
# [8 rows x 33 columns]
