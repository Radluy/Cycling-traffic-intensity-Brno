# %% [markdown]
# ### Import libraries

# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Read geojson file

# %%
df = gpd.read_file('../../datasets/cyklodetektory.geojson')

# %% [markdown]
# ### Clean the data

# %%
df['datum'] = pd.to_datetime(df['datum'])
df['EndOfInterval'] = pd.to_datetime(df['EndOfInterval'])

# %% [markdown]
# ### Basic dataset info
#
# 1. ID: `UnitId` + `datum` + `FirstDirection_Name`/`SecondDirection_Name`
# 2. Match to specific street/GIS: `Latitude` + `Longitude`
# 3. Useful information: `FirstDirection_Cyclists`, `SecondDirection_Cyclists`

# %%
display(df.head())
display(f"Shape: {df.shape}")
display(f"Columns: {df.columns}")
display(df.describe())
# Out:
#    ObjectId   ID       UnitName UnitId  LocationId   Latitude  Longitude  \
# 0         1  502     Renneska 1   CAM1           0  49.183699  16.602423
# 1         2  302         Obřany   CAM8           9  49.226283  16.658782
# 2         3  503     Renneska 2   CAM2           1  49.183642  16.602337
# 3         4  303  Královopolská   CAM9          10  49.218652  16.575043
# 4         5  504          Komín   CAM3           2  49.218533  16.540979
#
#               EndOfInterval FirstDirection_Name  FirstDirection_Cyclists  \
# 0 2021-06-22 03:59:59+00:00     Novosadský most                      6.0
# 1 2021-06-21 17:00:00+00:00              Obřany                      8.0
# 2 2021-06-22 03:59:59+00:00           Heršpická                     13.0
# 3 2021-06-21 02:00:00+00:00           Záhřebská                      0.0
# 4 2021-06-22 03:59:59+00:00               Komín                     12.0
#
#    FirstDirection_Pedestrians  FirstDirection_Total  SecondDirection_Name  \
# 0                         4.0                  10.0             Heršpická
# 1                         4.0                  12.0  Bílovice n. Svitavou
# 2                         3.0                  16.0              Renneska
# 3                         1.0                   1.0               Přívrat
# 4                         3.0                  15.0                Bystrc
#
#    SecondDirection_Cyclists  SecondDirection_Pedestrians  \
# 0                      18.0                         20.0
# 1                       5.0                          0.0
# 2                       5.0                          2.0
# 3                       0.0                          1.0
# 4                       1.0                          1.0
#
#    SecondDirection_Total                     datum                   geometry
# 0                     38 2021-06-22 02:00:00+00:00  POINT (16.60242 49.18370)
# 1                      5 2021-06-21 03:00:00+00:00  POINT (16.65878 49.22628)
# 2                      7 2021-06-22 02:00:00+00:00  POINT (16.60234 49.18364)
# 3                      1 2021-06-21 03:00:00+00:00  POINT (16.57504 49.21865)
# 4                      2 2021-06-22 02:00:00+00:00  POINT (16.54098 49.21853)
# 'Shape: (78048, 18)'
# "Columns: Index(['ObjectId', 'ID', 'UnitName', 'UnitId', 'LocationId', 'Latitude',\n       'Longitude', 'EndOfInterval', 'FirstDirection_Name',\n       'FirstDirection_Cyclists', 'FirstDirection_Pedestrians',\n       'FirstDirection_Total', 'SecondDirection_Name',\n       'SecondDirection_Cyclists', 'SecondDirection_Pedestrians',\n       'SecondDirection_Total', 'datum', 'geometry'],\n      dtype='object')"
#            ObjectId            ID    LocationId      Latitude     Longitude  \
# count  78048.000000  78048.000000  78048.000000  78048.000000  78048.000000
# mean   39024.500000  39025.499564      9.800226     49.192133     16.605029
# std    22530.661242  22530.661996     14.122859      0.024509      0.029944
# min        1.000000      0.000000      0.000000     49.145464     16.540979
# 25%    19512.750000  19513.750000      3.000000     49.183642     16.601318
# 50%    39024.500000  39025.500000      8.000000     49.201963     16.602423
# 75%    58536.250000  58537.250000     12.000000     49.203050     16.625437
# max    78048.000000  78049.000000     99.000000     49.240578     16.679649
#
#        FirstDirection_Cyclists  FirstDirection_Pedestrians  \
# count             50076.000000                50076.000000
# mean                 11.744129                    8.452672
# std                  23.761202                   22.188245
# min                   0.000000                    0.000000
# 25%                   0.000000                    0.000000
# 50%                   2.000000                    2.000000
# 75%                  12.000000                    9.000000
# max                 963.000000                  986.000000
#
#        FirstDirection_Total  SecondDirection_Cyclists  \
# count          51772.000000              76352.000000
# mean              19.879143                 10.180401
# std               37.239144                 18.210405
# min                0.000000                  0.000000
# 25%                0.000000                  0.000000
# 50%                6.000000                  2.000000
# 75%               22.000000                 13.000000
# max              986.000000                607.000000
#
#        SecondDirection_Pedestrians  SecondDirection_Total
# count                 50076.000000           78048.000000
# mean                      7.677091              14.993491
# std                      20.127811              27.377839
# min                       0.000000               0.000000
# 25%                       0.000000               0.000000
# 50%                       2.000000               5.000000
# 75%                       8.000000              18.000000
# max                     792.000000             822.000000

# %% [markdown]
# ### Correlation matrix
#
# Confirmed correlations:
# 1. between the number of cyclists and pedestrians in a single direction
# 2. between the number of cyclists in opposite directions
#
# Denied correlation:
# 1. between the number of pedestrians in a one direction and a number of cyclists in the opposite

# %%
corr_matrix = df.loc[:, ~df.columns.isin(['ObjectId', 'ID', 'LocationId', 'Latitude', 'Longitude'])].corr()
sns.heatmap(corr_matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Random exploring

# %%
df['UnitId'].unique()
df_summed = df.groupby(['UnitId']).sum()
display("SUM:",df_summed[['FirstDirection_Cyclists', 'SecondDirection_Cyclists']])
df_mean = df.groupby(['UnitId']).mean()
display("MEAN:",df_mean[['FirstDirection_Cyclists', 'SecondDirection_Cyclists']])

dataset_keys = df[['UnitId', 'datum']]
dataset_keys[dataset_keys['UnitId'] == 'CAM1'].sort_values('datum').head(10)
# Out:
# 'SUM:'
#         FirstDirection_Cyclists  SecondDirection_Cyclists
# UnitId
# CAM1                    63187.0                   61897.0
# CAM10                       0.0                   44951.0
# CAM11                       0.0                   27250.0
# CAM12                       0.0                   50199.0
# CAM13                       0.0                   30185.0
# CAM14                       0.0                   46931.0
# CAM15                       0.0                   42363.0
# CAM2                    37199.0                   35617.0
# CAM3                    86486.0                   82802.0
# CAM4                    91696.0                   93264.0
# CAM5                    17196.0                   11803.0
# CAM6                   146351.0                  114084.0
# CAM7                    44790.0                   44165.0
# CAM8                    52363.0                   53407.0
# CAM9                    32365.0                   16235.0
# LID1                     1097.0                     458.0
# LID2                    15369.0                   21683.0
# LID3                        0.0                       0.0
# LID4                        0.0                       0.0
# 'MEAN:'
#         FirstDirection_Cyclists  SecondDirection_Cyclists
# UnitId
# CAM1                  11.709970                 11.470904
# CAM10                       NaN                  8.217733
# CAM11                       NaN                  4.924106
# CAM12                       NaN                 18.886005
# CAM13                       NaN                 15.878485
# CAM14                       NaN                  8.528257
# CAM15                       NaN                  8.131094
# CAM2                   6.860752                  6.568978
# CAM3                  15.770605                 15.098833
# CAM4                  16.662911                 16.947847
# CAM5                  20.302243                 13.935065
# CAM6                  29.464667                 22.968391
# CAM7                  15.535900                 15.319112
# CAM8                   9.686090                  9.879208
# CAM9                   5.861101                  2.940058
# LID1                   0.252940                  0.105603
# LID2                   3.566721                  5.032026
# LID3                        NaN                       NaN
# LID4                        NaN                       NaN
#     UnitId                     datum
# 25    CAM1 2021-06-20 08:00:00+00:00
# 316   CAM1 2021-06-20 23:00:00+00:00
# 367   CAM1 2021-06-21 00:00:00+00:00
# 119   CAM1 2021-06-21 00:59:59+00:00
# 386   CAM1 2021-06-21 00:59:59+00:00
# 405   CAM1 2021-06-21 02:00:00+00:00
# 138   CAM1 2021-06-21 02:00:00+00:00
# 424   CAM1 2021-06-21 03:00:00+00:00
# 157   CAM1 2021-06-21 03:00:00+00:00
# 41    CAM1 2021-06-21 03:59:59+00:00
