# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('../datasets/rsd_scitanie_dopravy_2020.xlsx', skiprows=[0])

# %% [markdown]
# ### Basic dataset info
#
# 1. Match to specific street/GIS: weird section id format: `ÚSEK` [1-0136] and text explanation

# %%
display(df.head())
#display(f"Shape: {df.shape}")
#display("Columns:", df.columns)
#display(df.describe())
# Out:
#    PČ     KK  NÁZEV_KRAJE   SIL    ÚSEK  ÚSEK_N NÁZEV_MĚSTA  \
# 0   1  CZ020  Středočeský     4  1-0136     NaN         NaN
# 1   2  CZ020  Středočeský     4  1-0137  1-0138         NaN
# 2   3  CZ020  Středočeský     4  1-0138     NaN         NaN
# 3   4  CZ020  Středočeský     7  1-0740     NaN         NaN
# 4   5  CZ020  Středočeský  333M  1-7418     NaN         NaN
#
#                ZAČÁTEK ÚSEKU     KONEC ÚSEKU  \
# 0                vyús.ze 102    ul.Bartoňova
# 1               ul.Bartoňova    ul.K výtopně
# 2               ul.K výtopně        hr.Prahy
# 3                  vyús.z D0        hr.Prahy
# 4  hr.okr.Pha - vých.a Praha  konec sil.333M
#
#                        STANOVIŠTĚ SČÍTAČE  ...  I3-den I3-večer I3-noc I4-den  \
# 0            ul.Strakonická, u billboardu  ...    1163      109    199    150
# 1                                     NaN  ...    1067      100    188    179
# 2               ul.Strakonická, ČSPH MOL   ...    1067      100    188    179
# ...
